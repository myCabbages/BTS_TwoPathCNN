# %%
from keras import layers
from keras.layers import Input, Conv2D, Maximum, MaxPooling2D, concatenate, Activation
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
def two_path(X_input, arch_type):
    if arch_type == 'input':
        #upper path
        X = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((4,4), strides=(1,1), padding='valid')(X1)
        
        X = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X1)
        X1 = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X1)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((2,2), strides=(1,1), padding='valid')(X1)
        
        #lower path
        X = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Maximum()([X,X2])
        
        #concatenation
        X = concatenate([X1,X2], axis=3)
        X = Conv2D(5, (21, 21), strides=(1,1), padding='valid')(X)
        #X = Activation('softmax')(X)
    
        #model = Model(inputs=X_input, outputs=X)
        return X
    elif arch_type == 'local':
        #upper path
        X = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((4,4), strides=(1,1), padding='valid')(X1)
        
        #lower path
        X = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Maximum()([X,X2])
        
        return X1, X2
    elif arch_type == 'MF':
        #upper path
        X = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((4,4), strides=(1,1), padding='valid')(X1)
        
        X = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X1)
        X1 = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X1)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((2,2), strides=(1,1), padding='valid')(X1)
        
        #lower path
        X = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Maximum()([X,X2])
        #concatenation
        X = concatenate([X1,X2], axis=3)
        
        return X

# %%
m
# Out:
# <tf.Tensor 'activation_3/truediv:0' shape=(?, 33, 33, 5) dtype=float32>

# %%
def InputCascadeCNN(shape1, shape2):
    #concatenate input and output of the 1st two path network
    X1 = Input(shape1)
    X = two_path(X1, 'input')
    
    X2 = Input(shape2)
    X = concatenate([X, X2], axis=3)
    X = two_path(X, 'input')
    X = Activation('softmax')(X)
    
    model = Model(inputs=[X1,X2], outputs=X)
    return model

# %%
input1 = Input(shape = (65, 65, 4))

# %%
m = InputCascadeCNN((65,65,4), (33,33,4))
m.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_48 (InputLayer)           (None, 65, 65, 4)    0
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 59, 59, 64)   12608       input_48[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 59, 59, 64)   12608       input_48[0][0]
# __________________________________________________________________________________________________
# maximum_87 (Maximum)            (None, 59, 59, 64)   0           conv2d_197[0][0]
#                                                                  conv2d_198[0][0]
# __________________________________________________________________________________________________
# ...

# %%
def LocalCascadeCNN(shape1, shape2):
    X1 = Input(shape1)
    X = two_path(X1, 'input')
    
    X2 = Input(shape2)
    X21,X22 = two_path(X2, 'local')
    X21 = concatenate([X,X21], axis=3)
    X = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X21)
    X21 = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X21)
    X21 = Maximum()([X,X21])
    X21 = MaxPooling2D((2,2), strides=(1,1), padding='valid')(X21)
    
    X22 = concatenate([X21,X22], axis=3)
    X = Conv2D(5, (21, 21), strides=(1,1), padding='valid')(X21)
    X = Activation('softmax')(X)
    model = Model(inputs=[X1,X2], outputs=X)
    return model

# %%
ml = LocalCascadeCNN((56,56,4), (33,33,4))
ml.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_55 (InputLayer)           (None, 56, 56, 4)    0
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 50, 50, 64)   12608       input_55[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 50, 50, 64)   12608       input_55[0][0]
# __________________________________________________________________________________________________
# maximum_107 (Maximum)           (None, 50, 50, 64)   0           conv2d_243[0][0]
#                                                                  conv2d_244[0][0]
# __________________________________________________________________________________________________
# ...

# %%
def MFCascadeCNN(shape1,shape2):
    X1 = Input(shape1)
    X = two_path(X1, 'input')
    
    X2 = Input(shape2)
    X21 = two_path(X2, 'MF')
    X = concatenate([X,X21], axis=3)
    X = Conv2D(5, (21, 21), strides=(1,1), padding='valid')(X)
    X = Activation('softmax')(X)
    model = Model(inputs=[X1,X2], outputs=X)
    return model

# %%
mm = MFCascadeCNN((53,53,4),(33,33,4))
mm.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_59 (InputLayer)           (None, 53, 53, 4)    0
# __________________________________________________________________________________________________
# conv2d_271 (Conv2D)             (None, 47, 47, 64)   12608       input_59[0][0]
# __________________________________________________________________________________________________
# conv2d_272 (Conv2D)             (None, 47, 47, 64)   12608       input_59[0][0]
# __________________________________________________________________________________________________
# maximum_119 (Maximum)           (None, 47, 47, 64)   0           conv2d_271[0][0]
#                                                                  conv2d_272[0][0]
# __________________________________________________________________________________________________
# ...

# %%
def two_path3D(X_input, arch_type):
    if arch_type == 'input':
        #upper path
        X = Conv3D(64, (7, 7, 7), strides=(1,1,1), padding='valid')(X_input)
        X1 = Conv3D(64, (7, 7, 7), strides=(1,1,1), padding='valid')(X_input)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling3D((4,4,4), strides=(1,1,1), padding='valid')(X1)
        
        X = Conv3D(64, (3,3,3), strides=(1,1,1), padding='valid')(X1)
        X1 = Conv3D(64, (3,3,3), strides=(1,1,1), padding='valid')(X1)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling3D((2,2,2), strides=(1,1,1), padding='valid')(X1)
        
        #lower path
        X = Conv3D(160, (13, 13, 13), strides=(1,1,1), padding='valid')(X_input)
        X2 = Conv3D(160, (13, 13, 13), strides=(1,1,1), padding='valid')(X_input)
        X2 = Maximum()([X,X2])
        
        #concatenation
        X = concatenate([X1,X2], axis=4)
        X = Conv3D(5, (21, 21, 21), strides=(1,1,1), padding='valid')(X)
        X = Activation('softmax')(X)
    
        model = Model(inputs=X_input, outputs=X)
        return model
    elif arch_type == 'local':
        #upper path
        X = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((4,4), strides=(1,1), padding='valid')(X1)
        
        #lower path
        X = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Maximum()([X,X2])
        
        return X1, X2
    elif arch_type == 'MF':
        #upper path
        X = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Conv2D(64, (7, 7), strides=(1,1), padding='valid')(X_input)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((4,4), strides=(1,1), padding='valid')(X1)
        
        X = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X1)
        X1 = Conv2D(64, (3,3), strides=(1,1), padding='valid')(X1)
        X1 = Maximum()([X,X1])
        X1 = MaxPooling2D((2,2), strides=(1,1), padding='valid')(X1)
        
        #lower path
        X = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Conv2D(160, (13, 13), strides=(1,1), padding='valid')(X_input)
        X2 = Maximum()([X,X2])
        #concatenation
        X = concatenate([X1,X2], axis=3)
        
        return X

# %%
a1 = Input((103,320,232,1))
a2 = Input((232, 320, 103, 4))
tmp_in = Input((4, 232, 320, 103))
a1 = Conv3D(64, (7, 7, 7), strides=(1,1,1), padding='valid', data_format='channels_first')(a1)
a2 = Conv3D(64, (7, 7, 7), strides=(1,1,1), padding='valid')(a2)
a1
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/tf/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1588   try:
# -> 1589     c_op = c_api.TF_FinishOperation(op_desc)
#    1590   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 7 from 1 for 'conv3d_41/convolution' (op: 'Conv3D') with input shapes: [?,103,320,232,1], [7,7,7,103,64].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9d3fa161261a> in <module>()
#       2 a2 = Input((232, 320, 103, 4))
#       3 tmp_in = Input((4, 232, 320, 103))
# ----> 4 a1 = Conv3D(64, (7, 7, 7), strides=(1,1,1), padding='valid', data_format='channels_first')(a1)
# ...

# %%
from keras.layers import Conv3D, MaxPooling3D

# %%
m = two_path3D(tmp_in, 'input')
m.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_12 (InputLayer)           (None, 232, 320, 103 0
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 226, 314, 97, 87872       input_12[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 226, 314, 97, 87872       input_12[0][0]
# __________________________________________________________________________________________________
# maximum_10 (Maximum)            (None, 226, 314, 97, 0           conv3d_26[0][0]
#                                                                  conv3d_27[0][0]
# __________________________________________________________________________________________________
# ...
